# %% [markdown]
# ## Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## Reading Dataset

# %%
df = pd.read_csv('hotel_booking.csv')

# %% [markdown]
# ## Exploring the Data

# %% [markdown]
# ## Q1) Dataset overview: what do we have?

# %%
df.shape
# Out:
# (119390, 36)

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2       0.0       0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
list(df.columns)
# Out:
# ['hotel',
#  'is_canceled',
#  'lead_time',
#  'arrival_date_year',
#  'arrival_date_month',
#  'arrival_date_week_number',
#  'arrival_date_day_of_month',
#  'stays_in_weekend_nights',
#  'stays_in_week_nights',
#  'adults',
#  'children',
#  'babies',
#  'meal',
#  'country',
#  'market_segment',
#  'distribution_channel',
#  'is_repeated_guest',
#  'previous_cancellations',
#  'previous_bookings_not_canceled',
#  'reserved_room_type',
#  'assigned_room_type',
#  'booking_changes',
#  'deposit_type',
#  'agent',
#  'company',
#  'days_in_waiting_list',
#  'customer_type',
#  'adr',
#  'required_car_parking_spaces',
#  'total_of_special_requests',
#  'reservation_status',
#  'reservation_status_date',
#  'name',
#  'email',
#  'phone-number',
#  'credit_card']

# %% [markdown]
# ## **Q2) Column understanding (write 1 line per column)**

# %% [markdown]
# | Column                         | Meaning                                    | Expected Type        | Basic Rule                                |
# | ------------------------------ | ------------------------------------------ | -------------------- | ----------------------------------------- |
# | hotel                          | Type of hotel (City or Resort)             | Categorical          | Only 2 values (City Hotel / Resort Hotel) |
# | is_canceled                    | Whether booking was canceled (1=yes, 0=no) | Categorical (Binary) | Only 0 or 1                               |
# | lead_time                      | Days between booking date and arrival      | Numeric              | Non-negative                              |
# | arrival_date_year              | Year of arrival                            | Numeric              | Valid year (e.g., 2015–2017)              |
# | arrival_date_month             | Month of arrival                           | Categorical          | 12 valid month names                      |
# | arrival_date_week_number       | Week number of arrival                     | Numeric              | Between 1 and 53                          |
# | arrival_date_day_of_month      | Day of month of arrival                    | Numeric              | Between 1 and 31                          |
# | stays_in_weekend_nights        | Weekend nights stayed                      | Numeric              | Non-negative                              |
# | stays_in_week_nights           | Week nights stayed                         | Numeric              | Non-negative                              |
# | adults                         | Number of adults                           | Numeric              | Non-negative, usually ≥1                  |
# | children                       | Number of children                         | Numeric              | Non-negative, may contain nulls           |
# | babies                         | Number of babies                           | Numeric              | Non-negative                              |
# | meal                           | Type of meal plan                          | Categorical          | Limited predefined categories             |
# | country                        | Country of guest                           | Categorical          | 3-letter country codes                    |
# | market_segment                 | Booking market segment                     | Categorical          | Limited categories                        |
# | distribution_channel           | Booking distribution channel               | Categorical          | Limited categories                        |
# | is_repeated_guest              | If guest is repeated (1=yes, 0=no)         | Categorical (Binary) | Only 0 or 1                               |
# | previous_cancellations         | Previous canceled bookings                 | Numeric              | Non-negative                              |
# | previous_bookings_not_canceled | Previous successful bookings               | Numeric              | Non-negative                              |
# | reserved_room_type             | Initially reserved room type               | Categorical          | Single letter category                    |
# | assigned_room_type             | Assigned room type                         | Categorical          | Single letter category                    |
# | booking_changes                | Number of booking changes                  | Numeric              | Non-negative                              |
# | deposit_type                   | Type of deposit                            | Categorical          | No Deposit / Non Refund / Refundable      |
# | agent                          | Travel agent ID                            | Numeric (ID)         | Non-negative, may contain null            |
# | company                        | Company ID                                 | Numeric (ID)         | Non-negative, may contain null            |
# | days_in_waiting_list           | Days booking was in waiting list           | Numeric              | Non-negative                              |
# | customer_type                  | Type of customer                           | Categorical          | Limited categories                        |
# | adr                            | Average Daily Rate                         | Numeric (Float)      | Non-negative                              |
# | required_car_parking_spaces    | Required parking spaces                    | Numeric              | Non-negative                              |
# | total_of_special_requests      | Number of special requests                 | Numeric              | Non-negative                              |
# | reservation_status             | Reservation final status                   | Categorical          | Check-Out / Canceled / No-Show            |
# | reservation_status_date        | Date of reservation status                 | Date                 | Valid date format                         |

# %%
df.nunique().sort_values(ascending=False)
# Out:
# phone-number                      119390
# email                             115889
# name                               81503
# credit_card                         9000
# adr                                 8879
# reservation_status_date              926
# lead_time                            479
# company                              352
# agent                                333
# country                              177
# days_in_waiting_list                 128
# previous_bookings_not_canceled        73
# arrival_date_week_number              53
# stays_in_week_nights                  35
# arrival_date_day_of_month             31
# booking_changes                       21
# stays_in_weekend_nights               17
# previous_cancellations                15
# adults                                14
# assigned_room_type                    12
# arrival_date_month                    12
# reserved_room_type                    10
# market_segment                         8
# ...

# %% [markdown]
# ## Q3) Data types check: are types correct?

# %%
df.columns = df.columns.str.strip()
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %% [markdown]
# Identify columns that look wrong (numbers stored as text, dates stored as strings)
# Suggest conversion (to_numeric, to_datetime) Deliverable: list of “type problems” + proposed fix
# B) Data Quality (Missing, Duplicates, Validity)

# %%
df = df.rename(columns={
    'distribution_channel': 'booking_channel',
    'market_segment': 'customer_segment'
})

# %%
df.describe().T
# Out:
#                                    count         mean         std      min  \
# is_canceled                     119390.0     0.370416    0.482918     0.00
# lead_time                       119390.0   104.011416  106.863097     0.00
# arrival_date_year               119390.0  2016.156554    0.707476  2015.00
# arrival_date_week_number        119390.0    27.165173   13.605138     1.00
# arrival_date_day_of_month       119390.0    15.798241    8.780829     1.00
# stays_in_weekend_nights         119390.0     0.927599    0.998613     0.00
# stays_in_week_nights            119390.0     2.500302    1.908286     0.00
# adults                          119390.0     1.856403    0.579261     0.00
# children                        119386.0     0.103890    0.398561     0.00
# babies                          119390.0     0.007949    0.097436     0.00
# is_repeated_guest               119390.0     0.031912    0.175767     0.00
# ...

# %% [markdown]
# ## Q4) Missing values overview: where is data missing?

# %% [markdown]
# ## Data Quality (Missing, Duplicates, Validity)

# %%
missing = df.isnull().sum().sort_values(ascending=False)
print(missing)
# Out:
# company                           112593
# agent                              16340
# country                              488
# children                               4
# arrival_date_year                      0
# lead_time                              0
# is_canceled                            0
# hotel                                  0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# arrival_date_day_of_month              0
# arrival_date_month                     0
# babies                                 0
# meal                                   0
# customer_segment                       0
# booking_channel                        0
# is_repeated_guest                      0
# previous_cancellations                 0
# adults                                 0
# arrival_date_week_number               0
# reserved_room_type                     0
# previous_bookings_not_canceled         0
# booking_changes                        0
# ...

# %%
missing_percentage = (df.isnull().sum() / len(df)) * 100
high_missing_percentage= missing_percentage[missing_percentage>0]
print(high_missing_percentage.round(3))
# Out:
# children     0.003
# country      0.409
# agent       13.686
# company     94.307
# dtype: float64

# %% [markdown]
# ## Q5) Missing values strategy (IMPORTANT): how will you handle each missing column and why?

# %% [markdown]
# # **Missing Values Handling :**
#
# **children (0.003%)**: The missing percentage is extremely small, so these rows can be safely removed without affecting the dataset significantly.
#
# **country (0.409%)**: Since the percentage is very low, missing values can be removed without affecting the dataset significantly .
#
#
# -----------------
# # **Booking Source Feature Engineering:**
# **agent (13.686%)**: A noticeable percentage is missing. These likely represent direct bookings (not through an agent).
#
# **company (94.307%)**: The majority of values are missing, which suggests most bookings were not made through a company. This column has very low information value and can either be dropped
#
# *To better understand the booking channel, a new column called booking_source was created.*
# This feature categorizes each reservation into four groups:
#
# Agent Only: 31,187 bookings
#
# Company Only: 2,937 bookings
#
# Both (Agent & Company): 169 bookings
#
# Direct (No Agent & No Company): Remaining bookings
#
# The total number of bookings made through either an agent, a company, or both is 31,356.
#
# This transformation improves interpretability by replacing high-missing ID columns (agent and company) with a meaningful categorical feature that clearly represents the booking channel.

# %%
df.dropna(subset=['children'], inplace=True)

# %%
print(f'number of agent: {df["agent"].count()}')
print(f'number of company: {df["company"].count()}')
print(f'count of null rows in agent row : {df["agent"].isnull().sum()}')
print(f"count of null rows in company row : {df['company'].isnull().sum()}")
# Out:
# number of agent: 103048
# number of company: 6797
# count of null rows in agent row : 16338
# count of null rows in company row : 112589

# %%
df['booking_source'] = df.apply(
    lambda row: 'Company & Agent'
        if pd.notna(row['company']) and pd.notna(row['agent'])
    else ('Company'
        if pd.notna(row['company'])
    else ('Agent'
        if pd.notna(row['agent'])
    else 'Direct')),
    axis=1
)
df["booking_source"].value_counts()
# Out:
# booking_source
# Agent              102831
# Direct               9758
# Company              6580
# Company & Agent       217
# Name: count, dtype: int64

# %%
df = df.drop(['agent', 'company'], axis=1)

# %% [raw]
# Drop rows (only if missing is tiny)
#  Fill numeric with median
#  Fill categorical with "Unknown"
#  Drop the column (only if missing is extremely high and not useful)
#  Add a was_missing indicator (missing may carry meaning)
# Deliverable: “Missing Handling Plan”: column → action → reason

# %% [markdown]
# ## Q6) Duplicates check: are there exact duplicate rows?

# %% [markdown]
# ##  Duplicates check: are there exact duplicate rows?

# %%
n_dupes = df.duplicated().sum()
print(f"number of duplicate rows: {n_dupes}")
duplicated_rows = df[df.duplicated()]
# Out:
# number of duplicate rows: 0

# %% [markdown]
# ## **Q7) Key duplicates check (if an ID exists)**

# %% [markdown]
# Key Duplicates Check
# ID Column Check
#
# The dataset does not include a unique booking ID column (such as Booking_ID or Reservation_ID).
# Therefore, no column is expected to be strictly unique.

# %% [markdown]
# ## Q8) Validity rules: are there impossible values?

# %%
##fillnull
df['country'] = df['country'].fillna(df['country'].mode()[0])
[ ]
print(df['country'].isna().sum())
# Out:
# 0

# %%
##validation  adr should not be negative
negative_adr = df[df['adr'] < 0]
print(f"adr < 0: {len(negative_adr)}")
print(negative_adr[['hotel', 'adr', 'is_canceled']].head())
# Out:
# adr < 0: 1
#               hotel   adr  is_canceled
# 14969  Resort Hotel -6.38            0

# %%
## validation  customer should be adult
invalid_guests = df[(df['adults'] == 0) & (df['children'] == 0) & (df['babies'] == 0)]
print(len(invalid_guests))
# Out:
# 180

# %%
df = df[~((df['adults'] == 0) & (df['children'] == 0) & (df['babies'] == 0))].copy()
print(len(df))
# Out:
# 119206

# %%
df = df[df['adr'] >= 0].copy()

# %%
## invalid leadtime
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], errors='coerce')
max_date = df['reservation_status_date'].max()
future_dates = df[df['reservation_status_date'] > max_date]
df.loc[df['reservation_status_date'] > max_date, 'reservation_status_date'] = pd.NaT

# %% [markdown]
# ## Q9) Category cleanliness

# %%
categorical_cols = [
    'hotel',
    'meal',
    'country',
    'customer_segment',
    'booking_channel',
    'deposit_type',
    'customer_type',
    'reserved_room_type',
    'assigned_room_type',
    'reservation_status'
]

rows = []

for col in categorical_cols:
    if col in df.columns:
        print(f"\n{col.upper()}")
        print(df[col].value_counts(dropna=False).head(10))
        print("-"*50)
    else:
        print ({col})
summary_df = pd.DataFrame(rows)
# Out:
# HOTEL
# hotel
# City Hotel      79159
# Resort Hotel    40046
# Name: count, dtype: int64
# --------------------------------------------------
#
# MEAL
# meal
# BB           92231
# HB           14458
# SC           10549
# Undefined     1169
# FB             798
# Name: count, dtype: int64
# --------------------------------------------------
#
# COUNTRY
# country
# PRT    48957
# GBR    12119
# FRA    10401
# ESP     8560
# DEU     7285
# ITA     3761
# IRL     3374
# BEL     2342
# BRA     2222
# NLD     2103
# Name: count, dtype: int64
# --------------------------------------------------
#
# CUSTOMER_SEGMENT
# customer_segment
# Online TA        56407
# Offline TA/TO    24182
# Groups           19790
# Direct           12581
# Corporate         5282
# Complementary      728
# Aviation           235
# Name: count, dtype: int64
# --------------------------------------------------
#
# BOOKING_CHANNEL
# booking_channel
# TA/TO        97750
# Direct       14610
# Corporate     6651
# ...

# %% [raw]
# 1-Overall very good label consistency – no evidence of casing problems, extra spaces, multiple spellings of the same category, or obvious typos across important columns.
#
# 2-The only noticeable issue is the presence of "Undefined" in meal (1,169 records ≈ 1%).
#
# 3-→ This is the most significant cleaning action needed.
#
# 4-country contains 488 missing values (~0.4%) – acceptable for this dataset size and can be handled with a simple imputation strategy ("Unknown" / mode / leave as NaN).
#
# 5-"Undefined" in customer_segment and booking_channel is extremely rare (2 and 5 cases) → negligible impact.
#
# 7-All other major categorical fields (hotel, deposit_type, customer_type, room types, reservation_status) are completely clean

# %%
df['meal'] = df['meal'].replace('Undefined', 'SC')
df['meal'] = df['meal'].str.strip()

df['country'] = df['country'].str.upper().str.strip()

# %%
invalid_guests = df[(df['adults'] == 0) & (df['children'] == 0) & (df['babies'] == 0)]
print(len(invalid_guests))
# Out:
# 0

# %%
df = df[~((df['adults'] == 0) & (df['children'] == 0) & (df['babies'] == 0))].copy()
print(len(df))
# Out:
# 119205

# %%
df = df[df['adr'] >= 0].copy()

# %%
df['country'] = df['country'].str.upper().str.strip()

# %%
df.nunique()
# Out:
# hotel                                  2
# is_canceled                            2
# lead_time                            479
# arrival_date_year                      3
# arrival_date_month                    12
# arrival_date_week_number              53
# arrival_date_day_of_month             31
# stays_in_weekend_nights               17
# stays_in_week_nights                  33
# adults                                14
# children                               5
# babies                                 5
# meal                                   4
# country                              177
# customer_segment                       7
# booking_channel                        5
# is_repeated_guest                      2
# previous_cancellations                15
# previous_bookings_not_canceled        73
# reserved_room_type                     9
# assigned_room_type                    11
# booking_changes                       19
# deposit_type                           3
# ...

# %% [markdown]
# ## Minimal Cleaning Steps

# %%
df['room_changed'] = (df['reserved_room_type'] != df['assigned_room_type']).astype(int)

# %%
df['meal'] = df['meal'].replace('Undefined', 'SC')
df['meal'] = df['meal'].str.strip()

df['country'] = df['country'].str.upper().str.strip()

# %% [markdown]
# ### Q10) Numeric summary

# %%
num_cols = ['lead_time', 'stays_in_weekend_nights', 'stays_in_week_nights',
            'adults', 'children', 'babies', 'adr', 'booking_changes',
            'days_in_waiting_list', 'required_car_parking_spaces', 'total_of_special_requests']

df[num_cols].describe().round(2)
# Out:
#        lead_time  stays_in_weekend_nights  stays_in_week_nights     adults  \
# count  119205.00                119205.00              119205.0  119205.00
# mean      104.11                     0.93                   2.5       1.86
# std       106.88                     1.00                   1.9       0.58
# min         0.00                     0.00                   0.0       0.00
# 25%        18.00                     0.00                   1.0       2.00
# 50%        69.00                     1.00                   2.0       2.00
# 75%       161.00                     2.00                   3.0       2.00
# max       737.00                    19.00                  50.0      55.00
#
#        children     babies        adr  booking_changes  days_in_waiting_list  \
# count  119205.0  119205.00  119205.00        119205.00             119205.00
# mean        0.1       0.01     101.97             0.22                  2.32
# ...

# %% [raw]
# Strong right-skewness in: lead_time (mean 104 > median 69), adr (mean 102 > median 95), booking_changes, previous_cancellations, total_of_special_requests (mean >> median, most values = 0).
#
# Zero-inflated variables (median = 0): children, babies, total_of_special_requests, previous_cancellations, days_in_waiting_list, required_car_parking_spaces → >60–90% of records have zero in these fields.
#
# Typical booking profile: adults median = 2 (couples/small groups dominant), total nights usually 2–4, most guests request no parking or special requests.
#
# Clear outliers: adr max = 5400 and min = -6.38 → must be capped/removed/winsorized before modeling.
#
# Average nightly rate ~102 EUR, but median ~95 EUR → distribution pulled up by high-price outliers.
#
# One-line conclusion Dataset shows classic hospitality patterns: highly skewed, zero-inflated counts, small-group/short-stay dominance, and a few extreme adr values that need cleaning.

# %% [markdown]
# # Q11) Numeric distributions

# %%
import matplotlib.pyplot as plt
import seaborn as sns

key_cols = ['lead_time', 'adr', 'adults', 'children',
            'total_of_special_requests', 'booking_changes']

fig, axes = plt.subplots(2, 3, figsize=(15, 8))
axes = axes.ravel()

for i, col in enumerate(key_cols):
    sns.histplot(data=df, x=col, kde=True, ax=axes[i],
                 bins=40, color='teal')
    axes[i].set_title(f'Distribution of {col}')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Count')

plt.tight_layout()
plt.show()

# %% [raw]
# lead_time: Strong right skew → most bookings made shortly before arrival; long tail of early bookings (up to 737 days).
#
# adr: Right-skewed + extreme outliers → majority ~50–150 EUR; rare peaks >500 and one at 5400 (clear outlier).
#
# adults: Multimodal → clear peaks at 1 and 2 → single travelers and couples dominate.
#
# children & total_of_special_requests: Heavily zero-inflated → ~93% have 0 children, ~63% have 0 special requests.
#
# booking_changes: Extremely right-skewed & zero-inflated → vast majority make 0 changes.

# %% [markdown]
# # Q12) Outliers

# %%
plt.figure(figsize=(20, 15))
for i, col in enumerate(num_cols, 1):
  plt.subplot(4, 3, i)
  sns.boxplot(x=df[col],  color='deeppink')
  plt.title(f'Boxplot of {col}')

plt.show()

# %% [raw]
# Most severe outlier: adr (one negative value + one extreme 5400) → must be cleaned (cap or remove these 2–3 rows).
#
# lead_time has a realistic long tail → early bookings exist; no need to remove, but consider log transform for modeling.
#
# Count-based variables (changes, cancellations, requests) are zero-inflated with thin right tails → outliers are rare and often meaningful → keep or lightly group.
#
# Parking spaces and waiting list show few extreme cases → business-realistic, safe to keep

# %% [markdown]
# ## Q13) Categorical summary
# # Top 10 value counts for each categorical column

# %%
from IPython.display import display

for col in ['country', 'customer_segment', 'meal']:
    counts = df[col].value_counts()
    percentages = (df[col].value_counts(normalize=True) * 100).round(2)

    summary = pd.DataFrame({
        'Value': counts.index,
        'Count': counts.values,
        'Percentage (%)': percentages.values
    })

    print(f"\nUpdated Distribution for: {col}")
    display(summary)
# Out:
# Updated Distribution for: country
#     Value  Count  Percentage (%)
# 0     PRT  48957           41.07
# 1     GBR  12119           10.17
# 2     FRA  10401            8.73
# 3     ESP   8560            7.18
# 4     DEU   7285            6.11
# ..    ...    ...             ...
# 172   MRT      1            0.00
# 173   KIR      1            0.00
# 174   SDN      1            0.00
# 175   ATF      1            0.00
# 176   SLE      1            0.00
#
# [177 rows x 3 columns]
# Updated Distribution for: customer_segment
#            Value  Count  Percentage (%)
# 0      Online TA  56407           47.32
# 1  Offline TA/TO  24182           20.29
# 2         Groups  19790           16.60
# 3         Direct  12581           10.55
# 4      Corporate   5282            4.43
# 5  Complementary    728            0.61
# 6       Aviation    235            0.20
# Updated Distribution for: meal
#   Value  Count  Percentage (%)
# 0    BB  92231           77.37
# 1    HB  14458           12.13
# ...

# %%
cat_cols = [
    'hotel',
    'meal',
    'country',
    'customer_segment',
    'booking_channel',
    'deposit_type',
    'customer_type',
    'reserved_room_type',
    'assigned_room_type',
    'reservation_status'
]

summary_rows = []

for col in cat_cols:
    if col in df.columns:
        top = df[col].value_counts(dropna=False).head(8).reset_index()
        top.columns = ['Value', 'Count']
        top['Column'] = col
        top['Percentage'] = (top['Count'] / len(df) * 100).round(1)
        summary_rows.append(top[['Column', 'Value', 'Count', 'Percentage']])

top_categories = pd.concat(summary_rows, ignore_index=True)

top_categories.style \
    .format({'Count': '{:,}', 'Percentage': '{:.1f}%'}) \
    .background_gradient(subset=['Count'], cmap='Blues')
# Out:
# <style type="text/css">
# #T_958bc_row0_col2 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_958bc_row1_col2 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_958bc_row2_col2 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_958bc_row3_col2, #T_958bc_row22_col2, #T_958bc_row27_col2 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_958bc_row4_col2 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_958bc_row5_col2, #T_958bc_row19_col2, #T_958bc_row32_col2, #T_958bc_row40_col2, #T_958bc_row48_col2 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_958bc_row6_col2 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_958bc_row7_col2 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_958bc_row8_col2 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_958bc_row9_col2 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_958bc_row10_col2 {
#   background-color: #eaf2fb;
# ...

# %%
##save data
df.to_csv('cleaned_data.csv', index=False)

# %% [markdown]
# ## Q13) Categorical summary: what are the top categories?

# %%
drop_cols = [
    'name','email','phone-number','credit_card',
    'reservation_status','reservation_status_date',
    'arrival_date_week_number','arrival_date_day_of_month'
]

df = df.drop(columns=drop_cols)

# %%
cat_cols = df.select_dtypes(include='object').columns

for col in cat_cols:
    print(f"\n===== {col} =====\n")
    
    x = df[col].value_counts().head(10)
    y = round((x / len(df)) * 100,2)
    frequent = pd.DataFrame({
        "count": x,
        "percentage": y
    })
    
    print(frequent)
# Out:
# ===== hotel =====
#
#               count  percentage
# hotel
# City Hotel    79159       66.41
# Resort Hotel  40046       33.59
#
# ===== arrival_date_month =====
#
#                     count  percentage
# arrival_date_month
# August              13857       11.62
# July                12644       10.61
# May                 11780        9.88
# October             11147        9.35
# April               11078        9.29
# June                10929        9.17
# September           10500        8.81
# March                9767        8.19
# February             8052        6.75
# November             6771        5.68
#
# ===== meal =====
#
#       count  percentage
# meal
# BB    92231       77.37
# HB    14458       12.13
# SC    11718        9.83
# FB      798        0.67
#
# ===== country =====
#
#          count  percentage
# country
# PRT      48957       41.07
# GBR      12119       10.17
# FRA      10401        8.73
# ESP       8560        7.18
# DEU       7285        6.11
# ...

# %% [raw]
# Primary Business: Most of my guests stay in City Hotels and prefer Bed & Breakfast.
#
# Key Market: Portugal is my biggest market, with peak demand in August.
#
# Channels: I rely heavily on Online Agents, which brings high volume but high commissions.
#
# Risk: 87% of my bookings have No Deposit, making me vulnerable to cancellations.
#
# Operations: I frequently upgrade guests to manage room availability.

# %% [markdown]
# ## Q14) Rare categories: do we have categories that appear very few times?

# %%
for col in cat_cols:
    print(f"\n===== {col} =====\n")
    
    x = df[col].value_counts()
    y = round((x / len(df)) * 100,2)
    frequent = pd.DataFrame({
        "count": x,
        "percentage": y
    })
    
    rare = frequent[frequent["percentage"] < 3.00]
    
    if not rare.empty:
        print("Rare categories (<3%):")
        print(rare)
    else:
        print("No rare categories (<3%)\n")
# Out:
# ===== hotel =====
#
# No rare categories (<3%)
#
#
# ===== arrival_date_month =====
#
# No rare categories (<3%)
#
#
# ===== meal =====
#
# Rare categories (<3%):
#       count  percentage
# meal
# FB      798        0.67
#
# ===== country =====
#
# Rare categories (<3%):
#          count  percentage
# country
# IRL       3374        2.83
# BEL       2342        1.96
# BRA       2222        1.86
# NLD       2103        1.76
# USA       2093        1.76
# ...        ...         ...
# MRT          1        0.00
# KIR          1        0.00
# SDN          1        0.00
# ATF          1        0.00
# SLE          1        0.00
#
# [171 rows x 2 columns]
#
# ===== customer_segment =====
#
# Rare categories (<3%):
#                   count  percentage
# customer_segment
# Complementary       728        0.61
# Aviation            235        0.20
#
# ===== booking_channel =====
#
# Rare categories (<3%):
#                  count  percentage
# booking_channel
# ...

# %% [raw]
# Market Focus: Consolidate the 170+ minor countries into an "Other" category. Shift marketing budget from low-performing regions (like the USA/Ireland) to your "Top 5" markets to maximize ROI.
#
# Menu Optimization: Phasing out Full Board (FB) or reducing its overhead. Since guests don't use it, you can repurpose those kitchen resources for more popular Bed & Breakfast services.
#
# Channel Strategy: Minimize investment in GDS and Aviation channels. Instead, focus on reducing Online Agency (TA/TO) commissions by incentivizing Direct Bookings.
#
# Inventory Adjustment: Review your specialized room types (B, C, F, G). Since they are rarely booked, consider rebranding them or using them strictly for strategic upgrades to increase guest satisfaction.
#
# Policy Shift: To manage the "No Deposit" risk, introduce a small discount for Non-Refundable bookings to secure more guaranteed revenue.

# %% [markdown]
# ## Q15) Numeric relationships: which numeric columns move together?

# %% [markdown]
# ## Q19) Multivariate heatmap: visualize relationships clearly

# %%
num_df = df.select_dtypes(include=['int64','float64'])
corr = num_df.corr()

plt.figure(figsize=(15,8))
sns.heatmap(
    corr,
    annot=True,          
    fmt=".2f",          
    cmap="coolwarm",    
    center=0,           
    linewidths=0.5,      
    annot_kws={"size":9}
)

plt.title("Correlation Heatmap", fontsize=14)
plt.xticks(rotation=50, ha='right')
plt.yticks(rotation=0)

plt.show()

# %% [raw]
# The Cancellation Trap:
# Lead Time (0.29) is our biggest risk—the further out they book, the more likely they cancel. Conversely, guests who make Special Requests (-0.23) or ask for Parking (-0.20) are our "stickiest" and most reliable customers.
#
# The Family Revenue Engine:
# There is a clear "Family Cluster" where Children (0.33) and Adults (0.22) drive our highest ADR. Families aren't just guests; they are our primary high-yield revenue drivers.
#
# The Loyalty Loop:
# Repeat Guests show a strong (0.42) correlation with Previous Bookings Not Canceled. These are our lowest-risk assets; we should offer them the most flexible terms to keep them bypassing the OTAs.

# %%
corr_pairs = (
    corr.abs()
    .unstack()
    .sort_values(ascending=False)
)

top5 = corr_pairs[corr_pairs < 1].drop_duplicates().head(5)

top5
# Out:
# stays_in_weekend_nights  stays_in_week_nights              0.494152
# is_repeated_guest        previous_bookings_not_canceled    0.420641
# adr                      children                          0.325060
# lead_time                is_canceled                       0.292937
# room_changed             is_canceled                       0.246750
# dtype: float64

# %% [raw]
# Guests usually combine Weekends with Weekdays ($0.49$).
#
#  Repeat guests are most reliable; they rarely cancel ($0.42$).Revenue
#
#  Families with children significantly increase your ADR (daily rate) ($0.33$).
#
# Cancellation Risk: High Lead Time (booking too far in advance) is a top predictor of Cancellations ($0.29$).
#
# Commitment: Guests with Special Requests are more likely to actually show up ($0.23$).
#
#
# Target Families: They spend more.
#
# Reward Loyalty: Focus on repeat guests to lower cancellation risks.
#
# Watch Lead Time: Be stricter with deposits for bookings made months in advance.

# %% [markdown]
# ## Q16) Visual check: scatter plots for key numeric pairs

# %%
# Trend Line
plt.figure(figsize=(8, 5))
sns.regplot(data=df, x='stays_in_weekend_nights', y='stays_in_week_nights', 
            scatter_kws={'alpha':0.1}, line_kws={'color':'red'})
plt.title('Scatter Plot: Weekend vs Week Nights')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.regplot(data=df, x='children', y='adr', 
            scatter_kws={'alpha':0.1}, line_kws={'color':'green'})
plt.title('Scatter Plot: Children vs Average Daily Rate')
plt.show()

# %% [raw]
# Weekend vs. Week NightsInterpretation: The red trend line shows a positive correlation ; guests who stay during weekends are highly likely to extend their stay into the workweek. This indicates a "long-trip" pattern rather than short weekend getaways.
#
#
# Children vs. ADRInterpretation: There is a positive relationship showing that as the number of children increases, the Average Daily Rate (ADR) rises. This confirms that family bookings are a high-revenue segment for the hotel.

# %% [markdown]
# ## Q17) Category → numeric effect: does numeric change by category?

# %%
df.groupby('customer_segment')['adr'].agg(['mean','median']).sort_values(by='mean',ascending=False)
# Out:
#                         mean  median
# customer_segment
# Online TA         117.318746   109.8
# Direct            115.642833   105.0
# Aviation          100.994383    95.0
# Offline TA/TO      87.479307    85.5
# Groups             79.563963    70.0
# Corporate          69.528332    65.0
# Complementary       2.945838     0.0

# %%
stats = df.groupby('customer_segment')['adr'].agg(['mean', 'median']).sort_values(by='mean', ascending=False)
stats.plot(kind='bar', figsize=(10, 6))
plt.title('ADR Analysis: Mean vs Median by Customer Segment')
plt.ylabel('Rate (ADR)')
plt.xticks(rotation=45)
plt.show()

# %% [raw]
# customer_segment (Online & Direct)
# The Gap: Our high averages ($117.31) are driven by a few premium wins, while our "typical" booking (median) stays $7–$10 lower.
#
# The Solution: Raise our "floor" prices by 5–8% during peak days.
#
#
#
# The Gap: Corporate ($69.53) and Groups ($79.56) are stagnant. They don't scale up during busy periods, leaving money on the table.
#
# The Solution: Shift from "flat" contract rates to Dynamic % Discounts off our daily rate. This ensures our corporate revenue climbs automatically when market demand spikes.

# %%
df['total_revenue'] = df['adr'] * (df['stays_in_weekend_nights'] + df['stays_in_week_nights'])
revenue_share = df.groupby('customer_segment')['total_revenue'].sum()

revenue_filtered = revenue_share[revenue_share > (revenue_share.sum() * 0.01)]

plt.figure(figsize=(10, 7))
colors = sns.color_palette('pastel', len(revenue_filtered))

revenue_filtered.plot(kind='pie', autopct='%1.1f%%',  colors=colors,
                      wedgeprops={'edgecolor': 'white', 'linewidth': 2})

plt.title('Major Revenue Contributors (>1% Share)', fontsize=14, pad=20)
plt.ylabel('')
plt.show()

# %% [raw]
# Revenue Dominance: Online TA is the primary revenue driver at 56%, followed by Offline TA/TO at 19%. Small segments (Aviation, Corporate) were excluded from this view as their financial impact is negligible (near 0%).
# Action:
#  Since Online TA controls over half our revenue, negotiate better commission rates or shift 5-10% of this volume to Direct channels to save on fees.

# %% [markdown]
# ## Q18) Category ↔ category relationship (if possible)

# %%
pd.crosstab(df['hotel'], df['booking_channel'])
# Out:
# booking_channel  Corporate  Direct  GDS  TA/TO  Undefined
# hotel
# City Hotel            3386    6749  193  68831          0
# Resort Hotel          3265    7861    0  28919          1

# %% [raw]
# City Hotel: High Volume, High Cost
#  We are leaning too heavily on TA/TO (6,883) and GDS (1,936). While these channels fill rooms, the high commissions are eating our margins.
#
# Action: We need a aggressive "Book Direct" push. Shifting even 10% of that third-party traffic into our 6,749 Direct bookings will drastically increase our net profit without needing more guests.
#
# 2. Resort Hotel: Winning on Loyalty
# Our Resort is performing beautifully with 7,861 Direct bookings, nearly triple our TA/TO volume. This shows our guests are loyal and bypassing middlemen.
#
# Action: Focus on Ancillary Upselling. Since we aren't paying commissions on these 7,800+ guests, we should reinvest those savings into on-site offers (spa, dining, excursions) to maximize the total spend per stay.

# %% [markdown]
# ## Q20) Final EDA summary (simple but complete)

# %% [raw]
# Top 5 Insights:
#
# The Family Alpha: Family bookings with children are our primary revenue engine, showing a strong positive correlation (0.33) with our highest Average Daily Rates (ADR).
#
# The Long-Stay Pattern: There is a high correlation (0.49) between weekend and weekday stays, indicating our guests prefer extended trips over short getaways.
#
# The "Stickiness" Factor: Guests who make special requests or need parking are our most reliable; these features correlate with a significantly lower cancellation risk.
#
# Loyalty Stability: Repeat guests have a (0.42) correlation with successful stays, making them our lowest-risk and most predictable revenue stream
#
# Channel Dominance: Online TAs control $56\%$ of our revenue, providing high volume but creating a dangerous dependency on high-commission third parties.

# %% [raw]
# Top 5 Risks:
#
# Severe Cancellation Exposure: $87\%$ of bookings have "No Deposit," combined with a (0.29) correlation between long lead times and cancellations, leaving us highly vulnerable to revenue loss.
#
# Data Hygiene Issues: We have "Undefined" segments (15.00 ADR) and 710 unclassified bookings in the City Hotel that are currently "leaking" out of our analysis.
#
# Stagnant Corporate Pricing: Our Corporate and Group segments are "price-locked" with stagnant medians, failing to scale during peak demand periods.
#
# Underutilized Inventory: Specific room types (B, C, F, G) and meal plans (Full Board) are rarely booked, representing wasted operational overhead and messy inventory labels.
#
# Geographic : We have (170+) minor countries with negligible volume, which clutters our market reporting and dilutes our ROI focus.
